# %%
# Ilk Deneme

print('_Hello!_')

print('er')

print('TTT')
# Out:
# _Hello!_
# er
# TTT

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
import seaborn

# %%
x=np.linspace(0,1,300)
for w in range(2,6,2):
    plt.plot(x, np.sin(np.pi*x)*np.sin(2*w*np.pi*x))

# %%
# %pdb
# Out:
# Automatic pdb calling has been turned ON

# %%
from datetime import datetime

import pytz

utc = pytz.utc # utc is Coordinated Universal Time
ist = pytz.timezone('Asia/Istanbul') #IST is Indian Standard Time

now = datetime.now(tz=utc) # this is the current time in UTC
ist_now = now.astimezone(ist) # this is the current time in IST.
print(ist_now)
# Out:
# 2018-01-24 16:51:54.302703+03:00

# %%
import time
import urllib
import requests
import bs4

def find_first_link(url):
    response = requests.get(url)
    html = response.text
    soup = bs4.BeautifulSoup(html, "html.parser")

    # This div contains the article's body
    # (June 2017 Note: Body nested in two div tags)
    content_div = soup.find(id="mw-content-text").find(class_="mw-parser-output")

    # stores the first link found in the article, if the article contains no
    # links this value will remain None
    article_link = None

    # Find all the direct children of content_div that are paragraphs
    for element in content_div.find_all("p", recursive=False):
        # Find the first anchor tag that's a direct child of a paragraph.
        # It's important to only look at direct children, because other types
        # of link, e.g. footnotes and pronunciation, could come before the
        # first link to an article. Those other link types aren't direct
        # children though, they're in divs of various classes.
        if element.find("a", recursive=False):
            article_link = element.find("a", recursive=False).get('href')
            break

    if not article_link:
        return 

    # Build a full url from the relative article_link url
    first_link = urllib.parse.urljoin('https://en.wikipedia.org/', article_link)

    return first_link

# %%
# %timeit find_first_link("https://gir.im/https://tr.wikipedia.org/wiki/Bursa%27da_1999_T%C3%BCrkiye_genel_se%C3%A7imleri")
# Out:
# 542 ms ± 14.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
probability = [0.3602150537634409, 0.42028985507246375, 
  0.373117033603708, 0.36813186813186816, 0.32517482517482516, 
  0.4175257731958763, 0.41025641025641024, 0.39408866995073893, 
  0.4143222506393862, 0.34, 0.391025641025641, 0.3130841121495327, 
  0.35398230088495575]

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.random.normal(size = 1000)
plt.hist(x, normed=True, bins=30)
plt.ylabel('Çağrı Yanıtlama Oranı');

# %%
probability = ([7,0.3602150537634409], [8,0.42028985507246375])

# %%
plt.hist(probability)
plt.ylabel('Çağrı Yanıtlama Oranı');
